# %%
import requests
from bs4 import BeautifulSoup

def get_answers(text):
    i = 6
    for kp in range(10):
        link = f'https://stackoverflow.com/search?page={kp + 1}&pagesize=50&q={"+".join(text.split())}&sort=answers'
        answer = requests.get(link)

        soup = BeautifulSoup(answer.text, 'html.parser')
        post = soup.find_all('a', {'class': 'question-hyperlink'})

        questions = []
        answers = []

        for elem in post:
            try:
                questions.append(elem.text)
                answers.append(" ".join(BeautifulSoup(requests.get('https://stackoverflow.com' + elem['href']).text, 'html.parser').find_all('div', {'class': 'answer'})[0].text.split()))

                print(1)
                data.loc[i] = [questions[-1], answers[-1]]
                i += 1
                print(2)
            except Exception as e:
                print(e)

# %%
import pandas as pd

data = pd.read_csv('questions.csv')
data = data[["Question","Answer"]]
get_answers('python text')
# Out:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //askubuntu.com/questions/1231087/increase-font-size-of-terminal-in-a-no-gui-situation (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477B08>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //graphicdesign.stackexchange.com/questions/136851/why-does-modern-low-res-art-seem-to-look-better-than-retro-low-res-art (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477BC8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //puzzling.stackexchange.com/questions/97439/how-to-get-32-by-using-1-1-%c3%973-%c3%973-%c3%b72-%c3%b72-2-2 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477A60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //pm.stackexchange.com/questions/29584/how-do-i-overcome-a-bottleneck-in-a-teams-process-when-what-people-are-telling (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477B50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //chemistry.stackexchange.com/questions/132488/how-is-exact-racemization-possible (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477A48>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //music.stackexchange.com/questions/98858/how-to-configure-slur-with-tie-when-writing-choral-music (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477B68>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //politics.stackexchange.com/questions/52996/why-did-trumps-rally-round-the-flag-effect-evaporate-so-quickly (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477AD8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //astronomy.stackexchange.com/questions/35927/visible-stars-in-andromeda-galaxy (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477BB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //academia.stackexchange.com/questions/148166/can-a-person-who-once-supported-pseudoscience-or-conspiracy-theories-ever-be-con (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477AC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //buddhism.stackexchange.com/questions/38821/can-i-plan-for-future-while-doing-meditation-on-death (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477B98>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //cooking.stackexchange.com/questions/107895/kneading-causing-gluten (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //codegolf.stackexchange.com/questions/203797/generate-list-of-numbers-and-their-negative-counterparts (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477B20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //astronomy.stackexchange.com/questions/35938/any-online-planetarium-where-the-observer-is-on-another-celestial-body (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //stats.stackexchange.com/questions/462779/simulating-values-from-a-random-variable-that-is-a-sum-of-other-random-variables (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477988>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //physics.stackexchange.com/questions/546622/why-are-quantum-mechanical-observables-time-independent (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477A30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //scifi.stackexchange.com/questions/230421/why-isnt-the-whole-world-inside-a-suitcase (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477B80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //law.stackexchange.com/questions/50995/can-freelancers-publish-code-in-github-and-claim-it-to-be-theirs-repost (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477AF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //academia.stackexchange.com/questions/148142/emails-during-the-weekend (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477BE0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //english.stackexchange.com/questions/531801/what-is-middle-english-for-hello (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477AA8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //academia.stackexchange.com/questions/148186/how-to-parse-70-000-yr-for-9-months-employment-payable-over-12-months (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477B08>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //rpg.stackexchange.com/questions/168151/in-ghosts-of-saltmarsh-how-do-the-players-obtain-a-ship (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477BC8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //gardening.stackexchange.com/questions/51435/is-fertilizing-a-zero-sum-endeavor (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477BC8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //skeptics.stackexchange.com/questions/47460/has-sweden-tripled-its-icu-capacity-to-fight-covid-19 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x13477B50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //mathematica.stackexchange.com/questions/220405/shading-intersection-region (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x134779B8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# list index out of range
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# list index out of range
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# list index out of range
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# list index out of range
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# list index out of range
# list index out of range
# 1
# 2
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //music.stackexchange.com/questions/98858/how-to-configure-slur-with-tie-when-writing-choral-music (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12B8FF40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //literature.stackexchange.com/questions/13824/what-does-lady-macbeth-mean-by-what-thou-art-promised (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12B8
Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664040>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //worldbuilding.stackexchange.com/questions/174989/why-would-a-sleeper-ship-be-designed-to-only-wake-one-person-in-case-of-emergenc (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664058>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //money.stackexchange.com/questions/124409/can-stocks-trade-at-negative-prices (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664070>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //bitcoin.stackexchange.com/questions/95495/if-two-parties-submit-a-conflicting-transaction-between-each-other-how-does-the (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664040>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //math.stackexchange.com/questions/3640770/is-it-impossible-to-perfectly-fit-a-polynomial-to-a-trigonometric-function-on-a (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664058>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //codegolf.stackexchange.com/questions/203928/the-koszul-sign-rule (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664070>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //law.stackexchange.com/questions/50995/can-freelancers-publish-code-in-github-and-claim-it-to-be-theirs-repost (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664040>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //workplace.stackexchange.com/questions/157505/should-i-submit-an-incomplete-technical-interview-assignment (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664058>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //mathematica.stackexchange.com/questions/220405/shading-intersection-region (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664070>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='stackoverflow.comhttps', port=443): Max retries exceeded with url: //astronomy.stackexchange.com/questions/35938/any-online-planetarium-where-the-observer-is-on-another-celestial-body (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12664040>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
data.describe()
# Out:
#                                                  Question  \
# count                                                  21
# unique                                                 21
# top     \r\nQ: UnicodeDecodeError: 'charmap' codec can...
# freq                                                    1
#
#                                                    Answer
# count                                                  21
# unique                                                 20
# top     1789 This somewhat depends on what platform yo...
# freq                                                    2

# %%
data
# Out:
#                                              Question  \
# 0                                            Help me!
# 1                                  Python not working
# 2                                      Need some help
# 3                                         help needed
# 4                                     Windows crashed
# 5                   What does the “yield” keyword do?
# 6   \r\nQ: How to print colored text in terminal i...
# 7   \r\nQ: How do I download a file over HTTP usin...
# 8            \r\nQ: Print string to text file
# 9   \r\nQ: Python module for converting PDF to tex...
# 10  \r\n            A: How can I print literal cur...
# 11  \r\nQ: Selenium using Python - Geckodriver exe...
# 12  \r\nQ: Combine two columns of text in datafram...
# 13  \r\nQ: How do I run Python code from Sublime T...
# 14  \r\n            A: Is there a way to create mu...
# 15  \r\nQ: Extracting text from HTML file using Py...
# 16  \r\nQ: Python argparse: How to insert newline ...
# 17  \r\n            A: How to print colored text i...
# 18  \r\nQ: Rotate axis text in python matplotlib  ...
# 19  \r\n            A: UnicodeEncodeError: 'ascii'...
# 20  \r\nQ: UnicodeDecodeError: 'charmap' codec can...
# 21      \r\nQ: Python Text Editor(Very Basic)
# 22  \r\nQ: Python script to copy text to clipboard...
# 23  \r\n            A: Print string to text file\r...
# 24       \r\nQ: Python concatenate text files
# 25  \r\nQ: How do I find an element that contains ...
# 26  \r\nQ: Are dictionaries ordered in Python 3.6+...
# 27  \r\nQ: How do I print bold text in Python?    ...
# 28  \r\nQ: How to split a large text file into sma...
# 29  \r\nQ: Turn counter for python text adventure ...
# 30                \r\nQ: Python Text Encoding
# 31     \r\nQ: Sending HTML email using Python
# 32           \r\nQ: Python: Text saving issue
# 33  \r\nQ: Python - Text file into dictionary
# 34  \r\nQ: Python text processing/finding data    ...
# 35  \r\nQ: Unicode (UTF-8) reading and writing to ...
# 36  \r\nQ: How to read a text file into a list or ...
# 37       \r\nQ: Python text file modification
# 38  \r\nQ: How can I find all matches to a regular...
# 39             \r\nQ: Python text file to xml
# 40  \r\n            A: User input and command line...
# 41  \r\nQ: Ampersands are not being replaced with ...
# 42                 \r\nQ: Python Text Effects
# 43  \r\nQ: Python, text document to list? [closed]...
# 44  \r\nQ: Split Strings into words with multiple ...
# 45       \r\nQ: python text widget get method
# 46      \r\nQ: Python Text Based Map [closed]
# 47  \r\nQ: Easiest way to put python text game in ...
# 48         \r\nQ: Python Text file statistics
# 49  \r\nQ: How to check if text is “empty” (spaces...
# 50  \r\nQ: How can I read large text files in Pyth...
# 51  \r\nQ: Text processing - Python vs Perl perfor...
# 52          \r\nQ: Python Text Adventure Loop
# 53            \r\nQ: Python - Text Processing
# 54              \r\nQ: Python text extraction
# 55  \r\nQ: Python text search question [closed]   ...
#
#                                                Answer
# 0                                                  ok
# 1                                                 sad
# 2                                                here
# 3                                                  :)
# 4                                                 O_o
# 5   To understand what yield does you must underst...
# 6   1789 This somewhat depends on what platform yo...
# 7   446 In Python 2, use urllib2 which comes with ...
# 8   1191 text_file = open("Output.txt", "w") text_...
# 9   140 Try PDFMiner. It can extract text from PDF...
# 10  1996 You need to double the {{ and }}: >>> x =...
# 11  336 selenium.common.exceptions.WebDriverExcept...
# 12  479 if both columns are strings, you can conca...
# 13  370 Tools -> Build System -> (choose) Python t...
# 14  1786 You can use triple-quoted strings. When t...
# 15  134 html2text is a Python program that does a ...
# 16  383 Try using RawTextHelpFormatter: from argpa...
# 17  1789 This somewhat depends on what platform yo...
# 18  490 This works for me: plt.xticks(rotation=90)...
# 19  1350 You need to read the Python Unicode HOWTO...
# 20  908 The file in question is not using the CP12...
# 21  2 The error is pretty explicit: TypeError: coe...
# 22  166 See Pyperclip. Example (taken from Pypercl...
# 23  1191 text_file = open("Output.txt", "w") text_...
# 24  247 This should do it For large files: filenam...
# 25  314 Try the following: driver.find_elements_by...
# 26  486 Are dictionaries ordered in Python 3.6+? T...
# 27  338 class color: PURPLE = '\033' CYAN = '\...
# 28  840 Have you looked at the split command? $ sp...
# 29  1 Without seeing an example of your code, it's...
# 30  5 Yes, you need to know the encoding of the te...
# 31  413 From Python v2.7.14 documentation - 18.1.1...
# 32  2 To join a list of strings with newlines, use...
# 33  2 Let's process the file line per line, create...
# 34  1 file = open("Register.txt", "rt") lines = fi...
# 35  107 In the notation u'Capit\xe1n\n' the "\xe1"...
# 36  159 python's file.readlines() method returns a...
# 37  0 You can use a combination of the fileinput a...
# 38  527 Use re.findall or re.finditer instead. re....
# 39  2 I think easiest way would be to change your ...
# 40  495 To read user input you can try the cmd mod...
# 41  2 You're replacing the ampersand with an amper...
# 42  1 this sites may help you 1) http://www.pygame...
# 43  1 If you simply want to process the entire fil...
# 44  461 A case where regular expressions are justi...
# 45  2 When you get all text of the widget, there i...
# 46  2 use a package like curses to get 'direct' ac...
# 47  0 I am developing a website with python3.8 and...
# 48  1 There are a few problems with your code. Spe...
# 49  300 yourString.isspace() "Return true if there...
# 50  298 I provided this answer because Keith's, wh...
# 51  18 This is exactly the sort of stuff that Perl...
# 52  2 Use a while loop: obj1 = input(...) while ob...
# 53  0 I'm not 100% sure of what you're trying to d...
# 54  1 You need to track what section you are in as...
# 55  3 Let's see... return [x for x in document.spl...

# %%
data.to_csv("questions.csv")
